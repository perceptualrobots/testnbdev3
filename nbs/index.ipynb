# %%
#| hide
from testnbdev3.core import *

# %% [markdown]
# # testnbdev3
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install testnbdev3 in Development mode

# %% [markdown]
# ```sh
# # make sure testnbdev3 package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to testnbdev3
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/perceptualrobots/testnbdev3.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c perceptualrobots testnbdev3
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install testnbdev3
# ```
#
#
# [repo]: https://github.com/perceptualrobots/testnbdev3
# [docs]: https://perceptualrobots.github.io/testnbdev3/
# [pypi]: https://pypi.org/project/testnbdev3/
# [conda]: https://anaconda.org/perceptualrobots/testnbdev3

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/perceptualrobots/testnbdev3
# [docs]: https://perceptualrobots.github.io/testnbdev3/
# [pypi]: https://pypi.org/project/testnbdev3/
# [conda]: https://anaconda.org/perceptualrobots/testnbdev3

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
